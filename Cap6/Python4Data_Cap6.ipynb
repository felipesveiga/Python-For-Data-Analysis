# %%
import pandas as pd
from pandas import DataFrame, Series
import numpy as np
import csv
import json

#pd.read_csv('testep.csv', sep=';', index_col='message' ).fillna(str(0))

# %%
conda install lxml
# Out:
# ...
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.9.2
#   latest version: 4.10.3
#
# Please update conda by running
#
#     $ conda update -n base conda
#
#
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install beautifulsoup4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install html5lib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pd.read_csv('exemplo1.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-483b2b8fa5c0> in <module>
# ----> 1 pd.read_csv('exemplo1.csv')
#
# /srv/conda/envs/notebook/lib/python3.6/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     686     )
#     687
# ...

# %%
pd.read_csv('index_col_teste.csv', sep=';', index_col=['key1','key2'])
# Out:
#            value1  value2
# key1 key2
# one  a          1       2
#      b          3       4
#      c          5       6
#      d          7       8
# two  a          9      10
#      b         11      12
#      c         13      14
#      d         15      16

# %%
pd.read_csv('economia.csv',sep=',', index_col=[0,1])
# Out:
#                     Preço_Entrada  Preço_Saída
# País      Produtos
# Brasil    Maçã                100          200
#           Banana               50          150
#           Canela                7           25
# Argentina Maçã                200         1300
#           Banana               15           60
#           Canela                3           20

# %%
pd.read_csv('tabela_defeito.csv', sep='\s+')
# Out:
#       A   B   C   D
# aaa   1   2   3   4
# bbb   5   6   7   8
# ccc   9  10  11  12
# ddd  13  14  15  16

# %%
pd.read_csv('relatorio_shopping.csv', skiprows=[0,1,9], index_col=['Shopping', 'Loja'])
# Out:
#                       Aluguel
# Shopping    Loja
# Iguatemi    Adidas       1000
#             Zara          890
#             Spoleto       750
# Villa Lobos Adidas        850
#             Zara         1200
#             Spoleto       670
# Iguatemi    Nike          650

# %%
sentinels={'Preço':['não encontrei', 5.8]  ,
           'Lanche':['o Hot Dog é de frango'] } 
pd.read_csv('relatorio_estagiario.csv', na_values=sentinels, index_col=['Estádio','Lanche'] )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a963a43f39b7> in <module>
#       1 sentinels={'Preço':['não encontrei', 5.8]  ,
#       2            'Lanche':['o Hot Dog é de frango'] }
# ----> 3 pd.read_csv('relatorio_estagiario.csv', na_values=sentinels, index_col=['Estádio','Lanche'] )
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd
from pandas import DataFrame, Series
import numpy as np
vazio={'Espaço':'espaço vazio',
      'Aluguel':'a decidir'}
com='recomendo o espaço vazio do JK, ele é muito bom'
pd.read_csv('relatorio_estagio.csv', skiprows=[0,1,7], na_values=vazio, index_col=['Shopping', 'Espaço'],
           dayfirst=True)
# Out:
#                        Aluguel
# Shopping Espaço
# Eldorado Adidas          600.0
#          Ortobom         450.0
#          NaN             300.0
# JK       NaN             780.0
#          Zara            930.0
#          Calvin Klein      NaN

# %%
chunker=pd.read_csv('tabela_maluca.csv', chunksize=3)
tot=pd.Series([])
for piece in chunker:
    tot=tot.add(piece['key'].value_counts(), fill_value=0)
tot
# Out:
# /srv/conda/envs/notebook/lib/python3.6/site-packages/ipykernel_launcher.py:2: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
# a     4.0
# b     1.0
# b     1.0
# c     2.0
# q     1.0
# t     1.0
# z     2.0
# dtype: float64

# %%
pd.read_csv('series_c.csv').value_counts()
# Out:
# letra
# a        6
# w        3
# g        3
# b        2
# s        2
# o        2
# e        2
# j        2
# h        1
# c        1
# d        1
# f        1
# z        1
# x        1
# l        1
# m        1
# p        1
# t        1
# u        1
# k        1
# dtype: int64

# %%
a=pd.read_csv('tabela_maluca.csv')
#print(a)
tot=pd.Series([])
a.loc[:,['key']].value_counts().sort_values(ascending=False)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-a51ca6850412> in <module>
# ----> 1 a=pd.read_csv('tabela_maluca.csv')
#       2 #print(a)
#       3 tot=pd.Series([])
#       4 a.loc[:,['key']].value_counts().sort_values(ascending=False)
#
# ...

# %%
d={'Imigrantes (milhão)':[2,1.5,0.8,0.3,np.nan,0.5],
  'População':[32,21,11,24,14,7]}
data=pd.DataFrame(d, index=['SP','RJ', 'ES', 'MG','AM','PE'])
data['Fatia (%)']=data['Imigrantes (milhão)']/data['População'] *100
data
data.to_csv('composicao_populacional.csv', sep=',')

# %%
# !cat composicao_populacional.csv
# Out:
# ,Imigrantes (milhão),População,Fatia (%)
# SP,2.0,32,6.25
# RJ,1.5,21,7.142857142857142
# ES,0.8,11,7.272727272727273
# MG,0.3,24,1.25

# %%
import sys
data.to_csv(sys.stdout, sep='|', na_rep='NULL', index=False, header=False, columns=['Imigrantes (milhão)'])
# Out:
# 2.0
# 1.5
# 0.8
# 0.3
# NULL
# 0.5

# %%
primeira_semana=pd.date_range('24/10/2001',periods=7)
dias_vividos=pd.Series(np.arange(7), index=primeira_semana)
dias_vividos.to_csv(sys.stdout, index=False, header=False)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6

# %%
import csv
f=open('leitor.csv')
reader=csv.reader(f)
#for line in reader: print(line) 
with open('leitor.csv') as f:
    lines=list(csv.reader(f))

#print(lines)

header, values= lines[0], lines[1:]
print(values)
#for v in zip(*values):
    #print(v)

#for duo in zip(header, values):
    #print(duo)
data_dict={h: v for h, v in zip(header, zip(*values))}
print(data_dict)
# Out:
# [['1', '2', '3'], ['4', '5', '6']]
# {'a': ('1', '4'), 'b': ('2', '5'), 'c': ('3', '6')}

# %%
import csv
list(open('leitor.csv'))
list(csv.reader('leitor.csv'))
# Out:
# [['l'], ['e'], ['i'], ['t'], ['o'], ['r'], ['.'], ['c'], ['s'], ['v']]

# %%
s=[['palha','algodao'],['feijao','abobora'],['fogo','chuva']]

for pair in zip(*s):
    print(pair)
#double_l=list(l)
#t_l=list(double_l)
# Out:
# ('palha', 'feijao', 'fogo')
# ('algodao', 'abobora', 'chuva')

# %%
pairs = [(1, 'a'), (2, 'b'), (3, 'c'), (4, 'd')]
#numbers, letters = zip(*pairs)

for element in zip(*pairs):
    print(element)
# Out:
# (1, 2, 3, 4)
# ('a', 'b', 'c', 'd')

# %%
a=(('a','b','c'),[1,2,3],{'j','k','l'})
for element in zip(*a):
    print(element)
# Out:
# ('a', 1, 'j')
# ('b', 2, 'k')
# ('c', 3, 'l')

# %%
pd.read_csv('shopping.csv', skipinitialspace=True, index_col=[0,1])
# Out:
#                      Aluguel
# Shopping Espaço
# JK       Zara            900
#          Centauro        800
# Eldorado Mont Blanc      650
#          Vans            700

# %%
import csv
with open('teste_writer.csv','w') as f:
# Out:
#   File "<ipython-input-16-8090c158bf33>", line 3
#
#     ^
# SyntaxError: unexpected EOF while parsing

# %%
import json
obj="""
{"name":"Wes",
"places_lived":["United States","Spain","Germany"],
"pets":null,
"siblings":[{"name":"Scott",
            "age" :30,
            "pets":["Zeus","Zuko"]},
            {"name":"Katie",
            "age":38,
            "pets":["Sixes","Stache","Cisco"]}]}
            """
result=json.loads(obj)
result
#asjson=json.dumps(result)
#asjson
# Out:
# {'name': 'Wes',
#  'places_lived': ['United States', 'Spain', 'Germany'],
#  'pets': None,
#  'siblings': [{'name': 'Scott', 'age': 30, 'pets': ['Zeus', 'Zuko']},
#   {'name': 'Katie', 'age': 38, 'pets': ['Sixes', 'Stache', 'Cisco']}]}

# %%
irmaos=pd.DataFrame(result['siblings'], columns=['name','age'], index=[1,2])
irmaos
pd.DataFrame(result[['places_lived'])
# Out:
#                0
# 0  United States
# 1          Spain
# 2        Germany

# %%
numeros="""
[{"a": 1,"b":2,"c":3},
 {"a": 4,"b":5, "c":6},
 {"a": 7, "b":8, "c":9}]
"""
oi=pd.read_json(numeros)
oi
#pd.DataFrame(oi)
# Out:
#    a  b  c
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %%
teste_names="""
[{"name":"Wes","places_lived":"USA","pets":null},
 {"name":"Andrew","places_lived": "Mexico","pets": "Landon"}]
 """
#resultado=pd.read_json(teste_names)
json.loads(teste_names)
# Out:
# [{'name': 'Wes', 'places_lived': 'USA', 'pets': None},
#  {'name': 'Andrew', 'places_lived': 'Mexico', 'pets': 'Landon'}]

# %%
conda install Pytables
# Out:
# ...
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.9.2
#   latest version: 4.10.3
#
# Please update conda by running
#
#     $ conda update -n base conda
#
#
#
# ## Package Plan ##
#
#   environment location: /srv/conda/envs/notebook
#
#   added / updated specs:
#     - pytables
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2021.5.30  |       ha878542_0         136 KB  conda-forge
#     certifi-2021.5.30          |   py36h5fab9bb_0         141 KB  conda-forge
#     hdf5-1.10.6                |nompi_h6a2412b_1114         3.1 MB  conda-forge
#     lzo-2.10                   |    h516909a_1000         314 KB  conda-forge
#     mock-4.0.3                 |   py36h5fab9bb_1          51 KB  conda-forge
#     numexpr-2.7.3              |   py36h284efc9_0         200 KB  conda-forge
# ...

# %%
#pd.read_html('https://www.fdic.gov/resources/resolutions/bank-failures/failed-bank-list/')
a=pd.read_html('https://www.formula1.com/en/results.html/2021/races/1073/hungary/race-result.html', index_col='Pos')
f1=pd.DataFrame(a[0], columns=['No','Driver','Car','Time/Retired',  'PTS'])
f1
#pd.DataFrame(a, )
#b=pd.DataFrame(a[0], columns=['Driver','Car', 'PTS'])
#b
# Out:
#      No                    Driver                        Car Time/Retired  PTS
# Pos
# 1    31        Esteban  Ocon  OCO             Alpine Renault  2:04:43.199   25
# 2     5    Sebastian  Vettel  VET      Aston Martin Mercedes      +1.859s   18
# 3    44      Lewis  Hamilton  HAM                   Mercedes      +2.736s   15
# 4    55        Carlos  Sainz  SAI                    Ferrari     +15.018s   12
# 5    14     Fernando  Alonso  ALO             Alpine Renault     +15.651s   10
# 6    10        Pierre  Gasly  GAS           AlphaTauri Honda     +63.614s    9
# 7    22        Yuki  Tsunoda  TSU           AlphaTauri Honda     +75.803s    6
# 8     6     Nicholas  Latifi  LAT          Williams Mercedes     +77.910s    4
# 9    63      George  Russell  RUS          Williams Mercedes     +79.094s    2
# 10   33      Max  Verstappen  VER      Red Bull Racing Honda     +80.244s    1
# 11    7      Kimi  Räikkönen  RAI  Alfa Romeo Racing Ferrari       +1 lap    0
# ...

# %%
pd.read_json(
"""
[{"País":"Brasil", "PIB":2000},
{"PIB":100, "País":"Argentina"}]
""")
# Out:
#         País   PIB
# 0     Brasil  2000
# 1  Argentina   100

# %%
from lxml import objectify

path='testexm.xml'
parsed=objectify.parse(open(path))
root=parsed.getroot()
root.INDICATOR()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-796bbed22bc2> in <module>
#       4 parsed=objectify.parse(open(path))
#       5 root=parsed.getroot()
# ----> 6 root.INDICATOR()
#
# src/lxml/objectify.pyx in lxml.objectify.ObjectifiedElement.__getattr__()
#
# src/lxml/objectify.pyx in lxml.objectify._lookupChildOrRaise()
#
# AttributeError: no such child: {urn:schemas-microsoft-com:office:spreadsheet}INDICATOR

# %%
fazenda=pd.read_csv('fazenda.csv', skipinitialspace=True, index_col=0)
fazenda.to_pickle('fazenda_pickle')
pd.read_pickle('fazenda_pickle')
# Out:
#           Compra  Venda
# Produto
# Arroz         10     20
# Feijão         7     15
# Mandioca       5     12

# %%
frame=pd.DataFrame({'a':np.random.randn(100)})
store=pd.HDFStore('myfile.h5')
store['obj1']= frame
store['obj1_col']=frame['a']
store['obj1']
# Out:
#            a
# 0   0.933349
# 1  -0.373489
# 2   0.863884
# 3  -0.252608
# 4  -0.584956
# ..       ...
# 95 -0.345875
# 96  1.725941
# 97  0.025081
# 98  1.432429
# 99  1.887446
#
# [100 rows x 1 columns]

# %%
conda install pytables
# Out:
# ...
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.9.2
#   latest version: 4.10.3
#
# Please update conda by running
#
#     $ conda update -n base conda
#
#
#
# ## Package Plan ##
#
#   environment location: /srv/conda/envs/notebook
#
#   added / updated specs:
#     - pytables
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     hdf5-1.10.6                |nompi_h6a2412b_1114         3.1 MB  conda-forge
#     lzo-2.10                   |    h516909a_1000         314 KB  conda-forge
#     mock-4.0.3                 |   py36h5fab9bb_1          51 KB  conda-forge
#     numexpr-2.7.3              |   py36h284efc9_0         200 KB  conda-forge
#     pytables-3.6.1             |   py36hb7ec5aa_3         1.5 MB  conda-forge
#     ------------------------------------------------------------
# ...

# %%
corn=pd.HDFStore('fazend_.h5')
corn.put('milho', fazenda, format='table')
corn.select('milho')
corn.put('max', f1, format='table')
corn['max']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-4337e9e76ba3> in <module>
# ----> 1 corn=pd.HDFStore('fazend_.h5')
#       2 corn.put('milho', fazenda, format='table')
#       3 corn.select('milho')
#       4 corn.put('max', f1, format='table')
#       5 corn['max']
#
# NameError: name 'pd' is not defined

# %%
import csv
superm=pd.read_csv('compras.csv')
superm.to_pickle('mercado_pickle')
pd.read_pickle('mercado_pickle')

box=pd.HDFStore('caixa.h5')
box.put('teste_csv',superm, format='table')
box['teste_csv']

#csv.reader(open('compras.csv')).to_pickle('open_teste')
#to_pickle?
# Out:
#      Comprar   Preço
# 0      Arroz       5
# 1     Feijão       7
# 2     Frango      10
# 3  Beterraba       8

# %%
dropbox=pd.HDFStore('kaixa.h5')
df=pd.read_csv('prova.csv', skipinitialspace=True, index_col=0)
df.to_hdf('kaixa.h5', 'obj1', format='table')
dropbox[ 'obj1'].sort_values(by='Pontuação', ascending=False)
#pd.read_hdf('kaixa.h5', 'obj1')
# Out:
#            Pontuação
# Aluno
# Guilherme      830.6
# Ana            761.5
# Felipe         730.5
# Javier         350.6

# %%
pip install xlrd
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install openpyxl
# Out:
# ...
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.9.2
#   latest version: 4.10.3
#
# Please update conda by running
#
#     $ conda update -n base conda
#
#
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
sentinel={'Prdouto':'Arro', 'Status':'COMPRAR'}
arquivo_quebrado=pd.read_excel('veiga_supermercados.xls', 'Estoques' )
#arquivo_quebrado
arquivo_quebrado['Prdouto']=arquivo_quebrado['Prdouto'].replace('Arro','Arroz')
arquivo_quebrado['Status']=arquivo_quebrado['Status'].replace('OK', 'MANTER')
arquivo_quebrado.rename(columns={'Prdouto':'Produto', 'Status':'Condição'}, inplace=True)

arquivo_corrigido=arquivo_quebrado

caixa=pd.HDFStore('kaixinha.h5')
arquivo_corrigido.to_pickle('pickle.tt')
pd.read_pickle('pickle.tt')
arquivo_corrigido.to_hdf('kaixinha.h5', 'obj1', format='table')
caixa['obj1']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /srv/conda/envs/notebook/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Prdouto'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-2-dd70a201fbc0> in <module>
# ...

# %%
pip install xlrd
# Out:
# ...
#      |████████████████████████████████| 96 kB 3.0 MB/s eta 0:00:011
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install openpyxl
# Out:
# ...
#      |████████████████████████████████| 243 kB 4.3 MB/s eta 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pd.read_excel('veiga_supermercados.xlsx',engine='openpyxl', index_col=0)
# Out:
#                       Prdouto  Preço   Status
# Setor
# Alimentação              Arro      3  COMPRAR
# Alimentação            Feijão      4       OK
# Alimentação     Massa Lasanha     12       OK
# Higiene       Papel Higiênico     10       OK
# Higiene          Rexona Spray      7  COMPRAR
# Higiene      Sabonete Líquido      3       OK

# %%
feira=pd.read_csv('feira.csv', skipinitialspace=True)
criar=pd.ExcelWriter('teste_excel.xlsx')
feira.to_excel(criar, 'Sheet de feira')
criar.save()

# %%
writer=pd.ExcelWriter('idade.xlsx')
idade=pd.read_csv('idade.csv')
idade.to_excel(writer, 'Tabela de Idades')
writer.save()

# %%
import requests
resp=requests.get('https://ge.globo.com/futebol/brasileirao-serie-a/')
resp.ok
# Out:
# True

# %%
r=requests.get('https://s.glbimg.com/es/sde/f/organizacoes/2019/10/10/ceara.svg')
r.content
with open('ceara.jpg', 'wb') as f:
    f.write(r.content)

# %%
r=requests.get('https://g1.globo.com/politica/noticia/2021/08/03/cpi-fomos-usados-de-maneira-odiosa-diz-reverendo-que-negociou-vacinas-em-nome-do-governo.ghtml')
r.text
# Out:
# '<!DOCTYPE HTML>\n<html lang="pt-br"> <head><meta charset="utf-8"><meta http-equiv="x-ua-compatible" content="ie=edge,chrome=1"><meta name="viewport" content="width=device-width, initial-scale=1"><script type="text/javascript" id="CDA_AAS">\n  window.cdaaas = window.cdaaas || {};\n  window.cdaaas.SETTINGS = window.cdaaas.SETTINGS || {};\n  window.cdaaas.PAGE_ANALYTICS_DATA = {"adsCount":3,"channel":"desktop","contentId":"bae2c7c4-4b44-4c10-8640-a9ffbaf17a8b","contentType":"noticia","elementCount":16,"featuredElement":"","imageCount":0,"metadata":"wordCount=493\\u0026wordCountRange=491 a 700\\u0026multicontent-podcast=1\\u0026playlist=1\\u0026comments=true","pageType":"multi-content","paragraphCount":13,"serviceWorker":true,"videoCount":1};\n  window.cdaaas.helpers = window.cdaaas.helpers || {};\n  window.cdaaas.internals = {};\n  window.HorizonClient = new Promise((resolve) => { window.cdaaas.internals.resolveHorizonPromise = resolve; });\n</script><!-- Filers GCOM --><link rel="prec
# ...

# %%
payload={'page':2, 'count':25}
r=requests.get('https://httpbin.org/get', params=payload)
pd.DataFrame(r.json())
# Out:
#                 args                                   headers         origin  \
# count             25                                       NaN  34.71.221.157
# page               2                                       NaN  34.71.221.157
# Accept           NaN                                       */*  34.71.221.157
# Accept-Encoding  NaN                             gzip, deflate  34.71.221.157
# Host             NaN                               httpbin.org  34.71.221.157
# User-Agent       NaN                    python-requests/2.25.1  34.71.221.157
# X-Amzn-Trace-Id  NaN  Root=1-61098309-4f43f8ae09451da032638259  34.71.221.157
#
#                                                      url
# count            https://httpbin.org/get?page=2&count=25
# page             https://httpbin.org/get?page=2&count=25
# Accept           https://httpbin.org/get?page=2&count=25
# Accept-Encoding  https://httpbin.org/get?page=2&count=25
# Host             https://httpbin.org/get?page=2&count=25
# ...

# %%
a=requests.get('https://www.mambo.com.br/churrasco')
a.content
# Out:
# b'\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n  \n\n\n\n\n\n<!DOCTYPE html>\n\n\n\n\n\n\n<html lang="pt-BR" id="oracle-cc" data-bind="setContextVariable:{name:\'masterViewModel\', value:$data}" dir="ltr">\n<head>\n  <meta http-equiv="Content-Type" content="text/html; charset=utf-8">\n  <meta charset="utf-8">\n\n  \n  <script type="text/javascript">\n    window.isPreviewMode = false ;\n    if (window.isPreviewMode === false ){\n      var bActiveX;\n      try {\n        new ActiveXObject(\'Microsoft.XMLHTTP\');\n        bActiveX = true;\n      }\n      catch(e) { bActiveX = false; }\n      if (window.XMLHttpRequest || bActiveX) {\n        var xhttp = window.XMLHttpRequest ? new XMLHttpRequest() : new ActiveXObject(\'Microsoft.XMLHTTP\');\n        xhttp.onreadystatechange = function() {\n          if (this.readyState == 4 && this.status == 200) {\n            window.endpointRegistry = xhttp.response ;\n          }\n        };\n        xhttp.open("GET", "/ccstoreui/v1/reg
# ...

# %%
a=requests.post('https://www.mambo.com.br/ccstore/v1/images/?source=/file/v2975347193745608426/products/255317_HI_Linguica%20Cuiabana%20Gourmet%20Seara%20500g.jpg',
               data='esfiha')
with open('churrasss.jpg', 'wb') as g:
    g.write(a.content)

# %%
a=requests.get('https://m.facebook.com/felipe.veiga.79656', auth=('felipe.veiga.79656', 'dudu0603'))
a
# Out:
# <Response [200]>
